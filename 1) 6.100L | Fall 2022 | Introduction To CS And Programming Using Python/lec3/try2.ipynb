# %% [markdown]
# <a href="https://colab.research.google.com/github/ChanMin02/Self-Study/blob/main/1)%206.100L%20%7C%20Fall%202022%20%7C%20Introduction%20To%20CS%20And%20Programming%20Using%20Python/lec3/try2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Run this code and stop the infinite loop in your IDE

while True:
  print("noooooo")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# noooooo
# ...
